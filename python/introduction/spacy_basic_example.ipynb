# %%
# simple spacy example to exemplify  library methods
# Before execution, you should install spacy library properly 
# and also its dependencies.
#
# Portuguese model:
# python -m spacy download pt_core_news_sm
#
# Author: Fabrício Galende M. de Carvalho

import spacy

# Here we load the portuguese model
nlp = spacy.load('pt_core_news_sm')

my_document = nlp("Eu me chamo André Salerno. Aprendi tudo que o professor falou hoje!")

# %%
print("Sentence tokens contained in the document: ")
print("##################################################")
for sentence in my_document.sents:
    print(sentence.text)

print("##################################################\n\n")

print("Word tokens contained in the document: ")
print("##################################################")
for token in my_document:
    print("Word token:", token)
print("##################################################\n\n")
# Out:
# Sentence tokens contained in the document:
# ##################################################
# Eu me chamo André Salerno.
# Aprendi tudo que o professor falou hoje!
# ##################################################
#
#
# Word tokens contained in the document:
# ##################################################
# Word token: Eu
# Word token: me
# Word token: chamo
# Word token: André
# Word token: Salerno
# Word token: .
# Word token: Aprendi
# Word token: tudo
# Word token: que
# Word token: o
# Word token: professor
# Word token: falou
# Word token: hoje
# Word token: !
# ##################################################

# %%
# Now we can access token properties
for token in my_document:
    print("Token text: ", token.text)
    print("Token lemma: ", token.lemma_)
    print("Token POS TAG: ", token.pos_)
# Out:
# Token text:  Eu
# Token lemma:  eu
# Token POS TAG:  PRON
# Token text:  me
# Token lemma:  eu
# Token POS TAG:  PRON
# Token text:  chamo
# Token lemma:  chamar
# Token POS TAG:  VERB
# Token text:  André
# Token lemma:  André
# Token POS TAG:  PROPN
# Token text:  Salerno
# Token lemma:  Salerno
# Token POS TAG:  PROPN
# Token text:  .
# Token lemma:  .
# Token POS TAG:  PUNCT
# Token text:  Aprendi
# Token lemma:  Aprendi
# Token POS TAG:  VERB
# Token text:  tudo
# Token lemma:  tudo
# Token POS TAG:  PRON
# Token text:  que
# Token lemma:  que
# Token POS TAG:  SCONJ
# Token text:  o
# Token lemma:  o
# Token POS TAG:  DET
# Token text:  professor
# Token lemma:  professor
# Token POS TAG:  NOUN
# Token text:  falou
# Token lemma:  falar
# Token POS TAG:  VERB
# Token text:  hoje
# Token lemma:  hoje
# Token POS TAG:  ADV
# Token text:  !
# Token lemma:  !
# Token POS TAG:  PUNCT
