# %%
# simple nltk example to exemplify toolkit methods
# Before execution, you should install nltk library and 
# its dependencies.
#
# Author: Fabrício Galende M. de Carvalho


import nltk
import numpy as np


document = "As eleições de 2026 estão polarizadas. Nem Flávio nem Lula, o meu nome é André e eu não sei em quem votar" #in this case a paragraph.
sentences = nltk.sent_tokenize(document)
print("First sentence: ", sentences[0])
print("Second sentence: ", sentences[1])
# Out:
# First sentence:  As eleições de 2026 estão polarizadas.
# Second sentence:  Nem Flávio nem Lula, o meu nome é André e eu não sei em quem votar

# %%
# Now we split sentences in word tokens
words_sentence_0 = nltk.tokenize.word_tokenize(sentences[0])
print("Words from the first sentence: ", words_sentence_0)
# Out:
# Words from the first sentence:  ['As', 'eleições', 'de', '2026', 'estão', 'polarizadas', '.']

# %%
# if we want to install some modules or text corpora, we call nltk.download
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True
